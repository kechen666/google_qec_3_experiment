# %% [markdown]
# ## 尝试加速MLD算法

# %% [markdown]
# 我们发现虽然每个detector所连接的边和节点都是有限的，由于计算分布的规模随着边数量的增加而指数增加，因此依旧是一个比较大的数，最大可能为：
# $$2^{81}$$
# 这是一个很大的数，因此我们需要加速算法。

# %% [markdown]
# 我们考虑一个d=5，r=7的示例。

# %%
import MLD
import stim

# %%
circuit_noisy = stim.Circuit.from_file(".data/surface_code_bZ_d5_r07_center_5_5/circuit_noisy.stim")

detector_error_model = circuit_noisy.detector_error_model()

# %%
ml_decoder = MLD.MaxLikelihoodDecoder(detector_error_model,detector_error_model.num_detectors)
ml_decoder.compute_detector_number_distribution()
# Out:
# {'D0': 19,
#  'D3': 11,
#  'D17': 55,
#  'D4': 22,
#  'D13': 46,
#  'D16': 58,
#  'D18': 59,
#  'D19': 68,
#  'L0': 207,
#  'D1': 19,
#  'D23': 70,
#  'D5': 11,
#  'D22': 48,
#  'D26': 16,
#  'D27': 50,
#  'D2': 3,
#  'D6': 22,
#  'D14': 28,
#  'D20': 56,
#  'D24': 70,
#  'D7': 22,
#  'D28': 71,
#  'D30': 53,
#  'D8': 3,
#  'D33': 18,
#  'D9': 10,
#  'D25': 43,
#  'D10': 19,
#  'D29': 56,
#  'D31': 54,
#  'D11': 8,
#  'D34': 38,
#  'D21': 26,
#  'D32': 20,
#  'D35': 10,
#  'D12': 20,
#  'D41': 68,
#  'D37': 52,
#  'D40': 64,
#  'D36': 22,
#  'D15': 28,
#  'D42': 68,
#  'D43': 80,
#  'D44': 64,
#  'D38': 28,
#  'D47': 80,
#  'D46': 56,
#  'D39': 28,
#  'D48': 80,
#  'D49': 56,
#  'D51': 64,
#  'D50': 26,
#  'D52': 80,
#  'D53': 68,
#  'D45': 26,
#  'D54': 68,
#  'D55': 64,
#  'D56': 28,
#  'D57': 28,
#  'D58': 52,
#  'D59': 22,
#  'D65': 68,
#  'D61': 52,
#  'D64': 64,
#  'D60': 22,
#  'D66': 68,
#  'D67': 80,
#  'D68': 64,
#  'D62': 28,
#  'D71': 80,
#  'D70': 56,
#  'D63': 28,
#  'D72': 80,
#  'D73': 56,
#  'D75': 64,
#  'D74': 26,
#  'D76': 80,
#  'D77': 68,
#  'D69': 26,
#  'D78': 68,
#  'D79': 64,
#  'D80': 28,
#  'D81': 28,
#  'D82': 52,
#  'D83': 22,
#  'D89': 68,
#  'D85': 52,
#  'D88': 64,
#  'D84': 22,
#  'D90': 68,
#  'D91': 80,
#  'D92': 64,
#  'D86': 28,
#  'D95': 80,
#  'D94': 56,
#  'D87': 28,
#  'D96': 80,
#  'D97': 56,
#  'D99': 64,
#  'D98': 26,
#  'D100': 80,
#  'D101': 68,
#  'D93': 26,
#  'D102': 68,
#  'D103': 64,
#  'D104': 28,
#  'D105': 28,
#  'D106': 52,
#  'D107': 22,
#  'D113': 68,
#  'D109': 52,
#  'D112': 64,
#  'D108': 22,
#  'D114': 68,
#  'D115': 80,
#  'D116': 64,
#  'D110': 28,
#  'D119': 80,
#  'D118': 56,
#  'D111': 28,
#  'D120': 80,
#  'D121': 56,
#  'D123': 64,
#  'D122': 26,
#  'D124': 80,
#  'D125': 68,
#  'D117': 26,
#  'D126': 68,
#  'D127': 64,
#  'D128': 28,
#  'D129': 28,
#  'D130': 52,
#  'D131': 22,
#  'D137': 53,
#  'D133': 38,
#  'D136': 54,
#  'D132': 10,
#  'D138': 56,
#  'D139': 71,
#  'D140': 50,
#  'D134': 18,
#  'D143': 70,
#  'D142': 43,
#  'D135': 20,
#  'D144': 70,
#  'D145': 48,
#  'D147': 56,
#  'D146': 26,
#  'D148': 68,
#  'D149': 59,
#  'D141': 16,
#  'D150': 55,
#  'D151': 58,
#  'D152': 28,
#  'D153': 28,
#  'D154': 46,
#  'D155': 20,
#  'D156': 8,
#  'D157': 19,
#  'D160': 22,
#  'D162': 11,
#  'D159': 3,
#  'D161': 22,
#  'D158': 10,
#  'D163': 22,
#  'D166': 19,
#  'D165': 3,
#  'D164': 11,
#  'D167': 19}

# %% [markdown]
# ## 假设我们已知D43的值为0，对于D43的相关项，我们应该怎么处理？

# %%
D43_error_detector_model = {}

for error in detector_error_model:
    if error.type == "error":
        targets_copy = error.targets_copy()
        fliped_detector_observable_index = ml_decoder.get_detector_logical_observable_val(targets_copy, ml_decoder.detector_number)
        if 43 in fliped_detector_observable_index:
            probability = error.args_copy()[0]
            D43_error_detector_model[tuple(fliped_detector_observable_index)] = probability
            print(error)
# Out:
# error(0.00180976) D13 D16 D17 D43
# error(0.000500323) D13 D16 D40 D43
# error(0.00130303) D13 D16 D41 D43
# error(0.000457248) D13 D17 D41 D43
# error(0.00153124) D13 D40 D41 D43
# error(0.00367973) D13 D43
# error(0.000457248) D14 D16 D17 D43
# error(0.000457248) D14 D16 D41 D43
# error(0.00131259) D14 D17 D41 D43
# error(0.000577662) D14 D17 D43
# error(0.000577662) D14 D41 D43
# error(0.00131259) D14 D43
# error(0.00163785) D16 D17 D19 D43
# error(0.00025984) D16 D17 D20 D43
# error(0.000339969) D16 D19 D43 D47
# error(0.000970795) D16 D19 D43 D48
# error(0.00025984) D16 D20 D43 D48
# error(0.00122997) D16 D40 D42 D43
# error(0.000500323) D16 D41 D42 D43
# error(0.00116262) D16 D42 D43 D47
# error(0.000339969) D16 D42 D43 D48
# error(0.00025984) D17 D19 D43 D48
# error(0.00131677) D17 D20 D43 D48
# error(0.000320939) D17 D20 D43 D49
# error(0.00217206) D17 D41 D43 D44
# error(0.000577662) D17 D43 D44
# error(0.00237288) D17 D43 D44 D48
# error(0.000320939) D17 D43 D44 D49
# error(0.0320931) D19 D43
# error(0.00126654) D19 D43 D47 D48
# error(0.00131677) D20 D43
# error(0.000320939) D20 D43 D48 D49
# error(0.0117445) D37 D40 D41 D43
# error(0.0117445) D37 D43
# error(0.000278847) D39 D40 D42 D43
# error(0.000278847) D39 D40 D43 D66
# error(0.000278847) D39 D42 D43 D71
# error(0.000278847) D39 D43 D66 D71
# error(0.000500323) D40 D41 D42 D43
# error(0.00025984) D40 D41 D43 D44
# error(0.00163785) D40 D41 D43 D67
# error(0.00870461) D40 D42 D43 D47
# error(0.00164247) D40 D42 D43 D71
# error(0.00025984) D40 D43 D44 D72
# error(0.0010121) D40 D43 D66 D71
# error(0.000339969) D40 D43 D66 D72
# error(0.000339969) D40 D43 D67 D71
# error(0.000970795) D40 D43 D67 D72
# error(0.000577662) D41 D43 D44
# error(0.0147598) D41 D43 D44 D48
# error(0.00144021) D41 D43 D44 D72
# error(0.00025984) D41 D43 D67 D72
# error(0.0114407) D42 D43
# error(0.000289511) D42 D43 D46 D47
# error(0.000289511) D42 D43 D46 D71
# error(0.000339969) D42 D43 D47 D48
# error(0.00155311) D42 D43 D47 D71
# error(0.0182174) D43 D44
# error(0.00029241) D43 D44 D47 D48
# error(0.00029241) D43 D44 D47 D72
# error(0.000320939) D43 D44 D48 D49
# error(0.00110627) D43 D44 D48 D72
# error(0.000289511) D43 D46 D47 D75
# error(0.000289511) D43 D46 D71 D75
# error(0.0145662) D43 D47 D48 D52
# error(0.00149494) D43 D47 D48 D76
# error(0.00102062) D43 D47 D71 D75
# error(0.00043808) D43 D47 D71 D76
# error(0.00043808) D43 D47 D72 D75
# error(0.00127793) D43 D47 D72 D76
# error(0.00029241) D43 D48 D72 D76
# error(0.0145662) D43 D52
# error(0.0010121) D43 D66
# error(0.000339969) D43 D66 D71 D72
# error(0.0320931) D43 D67
# error(0.00126654) D43 D67 D71 D72
# error(0.00043808) D43 D71 D72 D75
# error(0.00154101) D43 D71 D72 D76
# error(0.00102062) D43 D75
# error(0.00357652) D43 D76

# %% [markdown]
# 多个错误事件同时发生的概率其实不大。

# %%
import itertools
probabilities = sorted(D43_error_detector_model.values(), reverse=True)

# %%
def get_i_error_even_probability(probabilities: list, i: int):
    """i个错误事件同时发生的概率

    Args:
        probabilities (list): 当前detector对应的所有错误事情
        i (int): i个错误事件发生
    """
    i_error_evens = itertools.combinations(range(len(probabilities)), i)
    i_error_even_probabilities = 0
    for error_even_index in i_error_evens:
        prob = 1
        for prob_index in range(len(probabilities)):
            if prob_index in error_even_index:
                prob = prob * probabilities[prob_index]
            else:
                prob = prob * (1 - probabilities[prob_index])
        i_error_even_probabilities += prob
    return i_error_even_probabilities

# %%
# for i in range(1,5):
#     i_probability = get_i_error_even_probability(probabilities=probabilities, i=i)
#     print(f"{i}个错误事件同时发生的概率为{i_probability}")

# %% [markdown]
# 假设，我们不考虑，错误事件组合，使得发生10^{-15}的概率。

# %%
probabilities[0]*probabilities[1]*probabilities[2]*probabilities[3]*probabilities[4]*probabilities[5]*probabilities[6]*probabilities[7]
# Out:
# 8.104974546600419e-15

# %% [markdown]
# 假设为1，则可能的组合是1,3,5,7.
# 假设为0，则可能的组合为0,2,4,6.
#
# 上面设置的10^{-15}次方，和其他时间发生，值应该更小，但是也存在一些可以合并的情况，可能对应会增加。
#
# 这个值如何设置，或者设置这个值是否会带来误差，需要进行思考。
#
# 因为，本身是probability存在顺序，因此我们可以有一定的优化：

# %%
probabilities
# Out:
# [0.03209314439133004,
#  0.03209314439133004,
#  0.018217423062421856,
#  0.014759755055715348,
#  0.014566244437595306,
#  0.014566244437595306,
#  0.011744456314717388,
#  0.011744456314717388,
#  0.011440706458813104,
#  0.008704607463930172,
#  0.003679729432590249,
#  0.0035765165723576037,
#  0.002372880000104484,
#  0.0021720613961547534,
#  0.0018097649976214288,
#  0.001642474710774992,
#  0.0016378526356232723,
#  0.0016378526356232723,
#  0.001553108689026702,
#  0.001541012847976231,
#  0.0015312353629818934,
#  0.001494935687764309,
#  0.0014402115842943254,
#  0.0013167694462953802,
#  0.0013167694462953802,
#  0.0013125946963400423,
#  0.0013125946963400423,
#  0.0013030340896023013,
#  0.001277933125358692,
#  0.0012665431220169816,
#  0.0012665431220169816,
#  0.0012299675340994892,
#  0.00116261892345543,
#  0.001106268851653764,
#  0.0010206214357338142,
#  0.0010206214357338142,
#  0.001012104479087138,
#  0.001012104479087138,
#  0.0009707951757025881,
#  0.0009707951757025881,
#  0.0005776624679265652,
#  0.0005776624679265652,
#  0.0005776624679265652,
#  0.0005776624679265652,
#  0.0005003234289882585,
#  0.0005003234289882585,
#  0.0005003234289882585,
#  0.0004572481909596582,
#  0.0004572481909596582,
#  0.0004572481909596582,
#  0.00043807971202203255,
#  0.00043807971202203255,
#  0.00043807971202203255,
#  0.00033996928787100034,
#  0.00033996928787100034,
#  0.00033996928787100034,
#  0.00033996928787100034,
#  0.00033996928787100034,
#  0.00033996928787100034,
#  0.0003209387535913488,
#  0.0003209387535913488,
#  0.0003209387535913488,
#  0.0003209387535913488,
#  0.0002924098249939555,
#  0.0002924098249939555,
#  0.0002924098249939555,
#  0.000289510702846385,
#  0.000289510702846385,
#  0.000289510702846385,
#  0.000289510702846385,
#  0.00027884701627162167,
#  0.00027884701627162167,
#  0.00027884701627162167,
#  0.00027884701627162167,
#  0.0002598401273406492,
#  0.0002598401273406492,
#  0.0002598401273406492,
#  0.0002598401273406492,
#  0.0002598401273406492,
#  0.0002598401273406492]

# %% [markdown]
# * 基于具体的测量值，为0则只能是偶数个错误事件发生，为1只能是奇数个错误事件发生。
# * 错误翻转是由几个错误事件发生而来。（多个错误事件发生，对应的概率会比较小）
#
# 因此，我们可以考虑设置一个阈值，选择出概率大于阈值的错误事件组合。

# %% [markdown]
# 这个后续继续考虑

# %% [markdown]
# ## d=3, r=3的并行在线MLD示例

# %%
import MLD
import stim

circuit_noisy = stim.Circuit.from_file("./data/surface_code_bZ_d3_r03_center_3_5/circuit_noisy.stim")

detector_error_model = circuit_noisy.detector_error_model()

# %% [markdown]
# 在均匀的噪声模型下，得到的基本情况为：
# ```
# L0:35
# max_key:D9, max_value:48
# connected_detector len:12
# max connectivity detector coordinates: [2.0, 4.0, 1.0]
# max connectivity detector: D9, detector indexs: [2, 5, 6, 8, 10, 13, 24, 12, 16, 7, 14, 11, 17], detector indexs len: 13
# max connectivity detector's connected detector coordinates: [[4.0, 4.0, 0.0], [2.0, 2.0, 1.0], [4.0, 2.0, 1.0], [0.0, 4.0, 1.0], [4.0, 4.0, 1.0], [2.0, 2.0, 2.0], [2.0, 0.0, 2.0], [0.0, 4.0, 2.0], [6.0, 2.0, 1.0], [4.0, 2.0, 2.0], [4.0, 6.0, 1.0], [2.0, 4.0, 2.0]]
# detector_error_model_number:24
# ```
#
# 意思是，在d=3, r=3的模型下，存在24个检测器（detector），其中最大连接数量的detector为D9，其相连的边数为48，其相连的detector数为13（因为是超图，所以连接边数!=连接节点数）。
#
# D9对应的坐标为[2.0, 4.0, 1.0]，其连接的detector为[[4.0, 4.0, 0.0], [2.0, 2.0, 1.0], [4.0, 2.0, 1.0], [0.0, 4.0, 1.0], [4.0, 4.0, 1.0], [2.0, 2.0, 2.0], [2.0, 0.0, 2.0], [0.0, 4.0, 2.0], [6.0, 2.0, 1.0], [4.0, 2.0, 2.0], [4.0, 6.0, 1.0], [2.0, 4.0, 2.0]].

# %%
detector_error_model
# Out:
# stim.DetectorErrorModel('''
#     error(0.00538601) D0 D2
#     error(0.00455203) D0 D2 D8
#     error(0.00341035) D0 D3
#     error(0.0287947) D0 D5
#     error(0.000418444) D0 D5 D7
#     error(0.00163539) D0 D5 D7 D8
#     error(0.00232627) D0 D5 D8
#     error(0.000500323) D0 D7 D8 D9
#     error(0.00153124) D0 D7 D8 D10
#     error(0.000418444) D0 D7 D8 L0
#     error(0.00167586) D0 D7 D9
#     error(0.000500323) D0 D7 D10
#     error(0.00480341) D0 D7 L0
#     error(0.000500323) D0 D8 D9
#     error(0.00175909) D0 D8 D10
#     error(0.000418444) D0 D8 L0
#     error(0.00167586) D0 D9
#     error(0.00547618) D0 D10
#     error(0.00897529) D0 L0
#     error(0.00400415) D1 D3
#     error(0.0299506) D1 D9
#     error(0.00278521) D1 L0
#     error(0.00724199) D2
#     error(0.00244636) D2 D5
#     error(0.00244636) D2 D5 D8
#     error(0.0231764) D2 D6
#     error(0.00218788) D2 D6 D8
#     error(0.00244473) D2 D8
#     error(0.00234426) D2 D8 D10
#     error(0.00234426) D2 D10
#     error(0.0121274) D3
#     error(0.00257744) D3 D9
#     error(0.000679707) D3 D9 D11
#     error(0.0333876) D3 D10
#     error(0.00249356) D3 D10 D11
#     error(0.00570877) D3 D11
#     error(0.0372781) D4
#     error(0.000689492) D4 D5 D6
#     error(0.000689492) D4 D5 D6 D16
#     error(0.0096422) D4 D5 D7 L0
#     error(0.00233472) D4 D5 D13
#     error(0.000418444) D4 D5 D13 D15
#     error(0.00163904) D4 D5 D13 D16
#     error(0.00235564) D4 D5 D15 L0
#     error(0.000418444) D4 D5 D16 L0
#     error(0.012185) D4 D5 L0
#     error(0.000689492) D4 D6 D13
#     error(0.000689492) D4 D6 D13 D16
#     error(0.0096422) D4 D7
#     error(0.023882) D4 D12
#     error(0.00145049) D4 D12 D13 L0
#     error(0.00109732) D4 D13 D15 L0
#     error(0.000418444) D4 D13 D16 L0
#     error(0.00288397) D4 D13 L0
#     error(0.00303188) D4 D15
#     error(0.00163904) D4 D16
#     error(0.0126275) D5 D6
#     error(0.000457248) D5 D6 D7 D8
#     error(0.000457248) D5 D6 D7 D16
#     error(0.0110294) D5 D6 D8
#     error(0.00162795) D5 D6 D8 D16
#     error(0.00179162) D5 D6 D16
#     error(0.0117445) D5 D7 D8 D10
#     error(0.00180976) D5 D7 D8 D18
#     error(0.000418444) D5 D7 D8 L0
#     error(0.00123866) D5 D7 D15 D17
#     error(0.000500323) D5 D7 D15 D18
#     error(0.00202284) D5 D7 D15 L0
#     error(0.000500323) D5 D7 D16 D17
#     error(0.00130303) D5 D7 D16 D18
#     error(0.00043829) D5 D7 D17
#     error(0.00153465) D5 D7 L0
#     error(0.000457248) D5 D8 D16 D18
#     error(0.000418444) D5 D8 L0
#     error(0.0117445) D5 D10
#     error(0.0276722) D5 D13
#     error(0.00163539) D5 D13 D15 D16
#     error(0.000689492) D5 D13 D16
#     error(0.000500323) D5 D15 D16 D17
#     error(0.00153124) D5 D15 D16 D18
#     error(0.000418444) D5 D15 D16 L0
#     error(0.00043829) D5 D15 D17
#     error(0.00043829) D5 D15 L0
#     error(0.00123866) D5 D17
#     error(0.00367973) D5 D18
#     error(0.0277541) D5 L0
#     error(0.0143031) D6
#     error(0.000457248) D6 D7 D8 D18
#     error(0.000457248) D6 D7 D16 D18
#     error(0.0130438) D6 D8
#     error(0.000577662) D6 D8 D16
#     error(0.00131259) D6 D8 D16 D18
#     error(0.000577662) D6 D8 D18
#     error(0.00175929) D6 D13
#     error(0.00175929) D6 D13 D16
#     error(0.0237929) D6 D14
#     error(0.00218788) D6 D14 D16
#     error(0.00186923) D6 D16
#     error(0.000577662) D6 D16 D18
#     error(0.00131259) D6 D18
#     error(0.044825) D7
#     error(0.0148931) D7 D8
#     error(0.000500323) D7 D8 D9 D10
#     error(0.00025984) D7 D8 D10
#     error(0.00163785) D7 D8 D10 D18
#     error(0.00025984) D7 D8 D18
#     error(0.0101579) D7 D9 D10
#     error(0.00182522) D7 D9 D17
#     error(0.0125586) D7 D9 L0
#     error(0.00129039) D7 D10 D17
#     error(0.000339969) D7 D10 D17 D19
#     error(0.000339969) D7 D10 D18
#     error(0.000970795) D7 D10 D18 D19
#     error(0.00025984) D7 D10 D19
#     error(0.0230303) D7 D15
#     error(0.00122997) D7 D15 D17 D18
#     error(0.00043829) D7 D15 D17 L0
#     error(0.00130303) D7 D16
#     error(0.000500323) D7 D16 D17 D18
#     error(0.00116262) D7 D17 D18
#     error(0.000339969) D7 D17 D18 D19
#     error(0.00152951) D7 D17 L0
#     error(0.00025984) D7 D18 D19
#     error(0.000970795) D7 D19
#     error(0.0545723) D8
#     error(0.000500323) D8 D9 D10
#     error(0.00274721) D8 D10
#     error(0.0147598) D8 D10 D11
#     error(0.00025984) D8 D10 D18 D19
#     error(0.00144021) D8 D10 D19
#     error(0.0147598) D8 D11
#     error(0.0275445) D8 D16
#     error(0.00217206) D8 D16 D18
#     error(0.000577662) D8 D18
#     error(0.00337289) D8 D18 D19
#     error(0.00454591) D8 D19
#     error(0.0115944) D9 D10
#     error(0.000679707) D9 D10 D11
#     error(0.0355187) D9 D17
#     error(0.0146857) D9 L0
#     error(0.036429) D10
#     error(0.0189373) D10 D11
#     error(0.00139803) D10 D11 D19
#     error(0.00129039) D10 D17
#     error(0.000339969) D10 D17 D19
#     error(0.0320931) D10 D18
#     error(0.00126654) D10 D18 D19
#     error(0.00263247) D10 D19
#     error(0.0448379) D11
#     error(0.0223958) D11 D19
#     error(0.0412356) D12
#     error(0.00137803) D12 D13 D14
#     error(0.0096422) D12 D13 D15 L0
#     error(0.00438123) D12 D13 D20
#     error(0.0134782) D12 D13 L0
#     error(0.00137803) D12 D14 D20
#     error(0.0096422) D12 D15
#     error(0.00582784) D12 D20 L0
#     error(0.0143739) D13 D14
#     error(0.000457248) D13 D14 D15
#     error(0.000457248) D13 D14 D15 D16
#     error(0.0126214) D13 D14 D16
#     error(0.0117445) D13 D15 D16 D18
#     error(0.00180976) D13 D15 D16 D23
#     error(0.000418444) D13 D15 D16 L0
#     error(0.00217451) D13 D15 D21
#     error(0.00180205) D13 D15 D23
#     error(0.00245936) D13 D15 L0
#     error(0.000457248) D13 D16 D23
#     error(0.0117445) D13 D18
#     error(0.0298663) D13 D20
#     error(0.00217451) D13 D21
#     error(0.0051997) D13 D23
#     error(0.0258279) D13 L0
#     error(0.0161189) D14
#     error(0.000457248) D14 D15 D16 D23
#     error(0.000457248) D14 D15 D23
#     error(0.0136064) D14 D16
#     error(0.00188874) D14 D16 D23
#     error(0.00351239) D14 D20
#     error(0.0258767) D14 D22
#     error(0.00188874) D14 D23
#     error(0.0473719) D15
#     error(0.0148931) D15 D16
#     error(0.000500323) D15 D16 D17 D18
#     error(0.00025984) D15 D16 D18
#     error(0.00163785) D15 D16 D18 D23
#     error(0.00025984) D15 D16 D23
#     error(0.00894996) D15 D17 D18
#     error(0.00182522) D15 D17 D21
#     error(0.0121309) D15 D17 L0
#     error(0.00025984) D15 D18
#     error(0.00162948) D15 D18 D21
#     error(0.0013101) D15 D18 D23
#     error(0.00322566) D15 D21 D23
#     error(0.00196646) D15 D21 L0
#     error(0.00025984) D15 D23
#     error(0.0573817) D16
#     error(0.00201621) D16 D18
#     error(0.0147598) D16 D18 D19
#     error(0.00025984) D16 D18 D23
#     error(0.0147598) D16 D19
#     error(0.00610158) D16 D23
#     error(0.0104561) D17 D18
#     error(0.000339969) D17 D18 D19
#     error(0.0355187) D17 D21
#     error(0.0131966) D17 L0
#     error(0.0380963) D18
#     error(0.0167732) D18 D19
#     error(0.00162948) D18 D21
#     error(0.0332784) D18 D23
#     error(0.0397037) D19
#     error(0.0139548) D20 D22
#     error(0.0160334) D20 D23
#     error(0.0575394) D20 L0
#     error(0.0195451) D21 D23
#     error(0.017823) D21 L0
#     error(0.0108271) D22
#     error(0.0505338) D23
#     detector(2, 5, 0) D0
#     detector(4, 3, 0) D1
#     detector(2, 7, 0) D2
#     detector(4, 5, 0) D3
#     detector(1, 4, 1) D4
#     detector(2, 5, 1) D5
#     detector(2, 7, 1) D6
#     detector(3, 4, 1) D7
#     detector(3, 6, 1) D8
#     detector(4, 3, 1) D9
#     detector(4, 5, 1) D10
#     detector(5, 6, 1) D11
#     detector(1, 4, 2) D12
#     detector(2, 5, 2) D13
#     detector(2, 7, 2) D14
#     detector(3, 4, 2) D15
#     detector(3, 6, 2) D16
#     detector(4, 3, 2) D17
#     detector(4, 5, 2) D18
#     detector(5, 6, 2) D19
#     detector(2, 5, 3) D20
#     detector(4, 3, 3) D21
#     detector(2, 7, 3) D22
#     detector(4, 5, 3) D23
# ''')

# %% [markdown]
# 我们发现上面的错误事件数为219个。

# %% [markdown]
# 我们先按照detector的序列顺序，执行在线的MLD算法。

# %%
ml_decoder = MLD.MaxLikelihoodDecoder(detector_error_model,detector_error_model.num_detectors)

ml_decoder.compute_detector_number_distribution()
# Out:
# {'D0': 19,
#  'D2': 10,
#  'D8': 43,
#  'D3': 8,
#  'D5': 45,
#  'D7': 48,
#  'D9': 16,
#  'D10': 34,
#  'L0': 35,
#  'D1': 3,
#  'D6': 26,
#  'D11': 10,
#  'D4': 20,
#  'D16': 48,
#  'D13': 34,
#  'D15': 43,
#  'D12': 10,
#  'D18': 45,
#  'D17': 26,
#  'D14': 16,
#  'D19': 20,
#  'D20': 8,
#  'D23': 19,
#  'D21': 10,
#  'D22': 3}

# %%
# 创建一个syndrome
import logging
from config import setup_logging

n=1
syndrome = "1"*n + "0"*(ml_decoder.detector_number-n)

setup_logging(environment='development', log_file_name = "speed_up_mld.log")
ml_decoder.decode([syndrome])
# Out:
# 2024-10-09 19:40:07,832 - MLD - DEBUG - detector index: 0, uncomputed and connected edge number: 19, probability distribution length: 128
# 2024-10-09 19:40:07,836 - MLD - DEBUG - detector index: 1, uncomputed and connected edge number: 3, probability distribution length: 128
# 2024-10-09 19:40:07,843 - MLD - DEBUG - detector index: 2, uncomputed and connected edge number: 8, probability distribution length: 256
# 2024-10-09 19:40:07,849 - MLD - DEBUG - detector index: 3, uncomputed and connected edge number: 6, probability distribution length: 256
# 2024-10-09 19:40:08,090 - MLD - DEBUG - detector index: 4, uncomputed and connected edge number: 20, probability distribution length: 4096
# 2024-10-09 19:40:09,086 - MLD - DEBUG - detector index: 5, uncomputed and connected edge number: 30, probability distribution length: 8192
# 2024-10-09 19:40:09,425 - MLD - DEBUG - detector index: 6, uncomputed and connected edge number: 14, probability distribution length: 8192
# 2024-10-09 19:40:10,183 - MLD - DEBUG - detector index: 7, uncomputed and connected edge number: 24, probability distribution length: 8192
# 2024-10-09 19:40:10,400 - MLD - DEBUG - detector index: 8, uncomputed and connected edge number: 12, probability distribution length: 4096
# 2024-10-09 19:40:10,439 - MLD - DEBUG - detector index: 9, uncomputed and connected edge number: 4, probability distribution length: 2048
# 2024-10-09 19:40:10,476 - MLD - DEBUG - detector index: 10, uncomputed and connected edge number: 8, probability distribution length: 1024
# 2024-10-09 19:40:10,481 - MLD - DEBUG - detector index: 11, uncomputed and connected edge number: 2, probability distribution length: 512
# 2024-10-09 19:40:10,496 - MLD - DEBUG - detector index: 12, uncomputed and connected edge number: 8, probability distribution length: 512
# 2024-10-09 19:40:10,544 - MLD - DEBUG - detector index: 13, uncomputed and connected edge number: 16, probability distribution length: 1024
# 2024-10-09 19:40:10,566 - MLD - DEBUG - detector index: 14, uncomputed and connected edge number: 8, probability distribution length: 1024
# 2024-10-09 19:40:10,604 - MLD - DEBUG - detector index: 15, uncomputed and connected edge number: 15, probability distribution length: 512
# 2024-10-09 19:40:10,611 - MLD - DEBUG - detector index: 16, uncomputed and connected edge number: 6, probability distribution length: 256
# 2024-10-09 19:40:10,616 - MLD - DEBUG - detector index: 17, uncomputed and connected edge number: 4, probability distribution length: 128
# 2024-10-09 19:40:10,618 - MLD - DEBUG - detector index: 18, uncomputed and connected edge number: 4, probability distribution length: 64
# 2024-10-09 19:40:10,621 - MLD - DEBUG - detector index: 19, uncomputed and connected edge number: 1, probability distribution length: 32
# 2024-10-09 19:40:10,622 - MLD - DEBUG - detector index: 20, uncomputed and connected edge number: 3, probability distribution length: 16
# 2024-10-09 19:40:10,624 - MLD - DEBUG - detector index: 21, uncomputed and connected edge number: 2, probability distribution length: 8
# 2024-10-09 19:40:10,625 - MLD - DEBUG - detector index: 22, uncomputed and connected edge number: 1, probability distribution length: 4
# 2024-10-09 19:40:10,626 - MLD - DEBUG - detector index: 23, uncomputed and connected edge number: 1, probability distribution length: 2
# 2024-10-09 19:40:10,627 - MLD - INFO - error, use logical flip, the correct probability rate is 0.963646380976628
# [0]

# %% [markdown]
# 输出按照顺序解码，每一步计算概率分布过程信息。

# %% [markdown]
# 简单探索一下随着d和r的增加，在线MLD的S_{max}变化。

# %%
# for d in range(3, 8, 2):

for r in range(1, 12, 2):
    # print(f"------------------------r:{r}, d:{d}-------------------------")
    logging.info(f"----------------------r: {r}, d: {d}-------------------------")
    surface_code_circuit = stim.Circuit.generated(
        "surface_code:rotated_memory_z",
        rounds=r,
        distance=3,
        after_clifford_depolarization=0.001,
        after_reset_flip_probability=0.002,
        before_measure_flip_probability=0.004,
        before_round_data_depolarization=0.003)
    
    surface_code_detector_model = surface_code_circuit.detector_error_model()
    ml_decoder = MLD.MaxLikelihoodDecoder(surface_code_detector_model, surface_code_detector_model.num_detectors)
    
    n=1
    syndrome = "1"*n + "0"*(ml_decoder.detector_number-n)

    setup_logging(environment='development', log_file_name = "speed_up_mld_d_3_r.log")
    ml_decoder.decode([syndrome])
# Out:
# 2024-10-09 20:07:16,182 - root - INFO - ----------------------r: 1, d: 5-------------------------
# 2024-10-09 20:07:16,215 - MLD - DEBUG - detector index: 0, uncomputed and connected edge number: 3, probability distribution length: 4
# 2024-10-09 20:07:16,217 - MLD - DEBUG - detector index: 1, uncomputed and connected edge number: 4, probability distribution length: 16
# 2024-10-09 20:07:16,219 - MLD - DEBUG - detector index: 2, uncomputed and connected edge number: 5, probability distribution length: 32
# 2024-10-09 20:07:16,222 - MLD - DEBUG - detector index: 3, uncomputed and connected edge number: 4, probability distribution length: 32
# 2024-10-09 20:07:16,224 - MLD - DEBUG - detector index: 4, uncomputed and connected edge number: 2, probability distribution length: 16
# 2024-10-09 20:07:16,225 - MLD - DEBUG - detector index: 5, uncomputed and connected edge number: 2, probability distribution length: 8
# 2024-10-09 20:07:16,227 - MLD - DEBUG - detector index: 6, uncomputed and connected edge number: 2, probability distribution length: 4
# 2024-10-09 20:07:16,228 - MLD - DEBUG - detector index: 7, uncomputed and connected edge number: 1, probability distribution length: 2
# 2024-10-09 20:07:16,229 - MLD - INFO - no error, no use logical flip, the correct probability rate is 0.9903950578802072
# 2024-10-09 20:07:16,230 - root - INFO - ----------------------r: 3, d: 5-------------------------
# 2024-10-09 20:07:16,235 - MLD - DEBUG - detector index: 0, uncomputed and connected edge number: 3, probability distribution length: 4
# 2024-10-09 20:07:16,239 - MLD - DEBUG - detector index: 1, uncomputed and connected edge number: 7, probability distribution length: 32
# 2024-10-09 20:07:16,251 - MLD - DEBUG - detector index: 2, uncomputed and connected edge number: 18, probability distribution length: 256
# 2024-10-09 20:07:16,261 - MLD - DEBUG - detector index: 3, uncomputed and connected edge number: 8, probability distribution length: 256
# 2024-10-09 20:07:16,268 - MLD - DEBUG - detector index: 4, uncomputed and connected edge number: 7, probability distribution length: 256
# 2024-10-09 20:07:16,314 - MLD - DEBUG - detector index: 5, uncomputed and connected edge number: 22, probability distribution length: 512
# 2024-10-09 20:07:16,381 - MLD - DEBUG - detector index: 6, uncomputed and connected edge number: 20, probability distribution length: 512
# 2024-10-09 20:07:16,456 - MLD - DEBUG - detector index: 7, uncomputed and connected edge number: 16, probability distribution length: 2048
# 2024-10-09 20:07:16,474 - MLD - DEBUG - detector index: 8, uncomputed and connected edge number: 4, probability distribution length: 1024
# 2024-10-09 20:07:16,559 - MLD - DEBUG - detector index: 9, uncomputed and connected edge number: 20, probability distribution length: 1024
# 2024-10-09 20:07:16,599 - MLD - DEBUG - detector index: 10, uncomputed and connected edge number: 17, probability distribution length: 512
# 2024-10-09 20:07:16,611 - MLD - DEBUG - detector index: 11, uncomputed and connected edge number: 8, probability distribution length: 512
# 2024-10-09 20:07:16,620 - MLD - DEBUG - detector index: 12, uncomputed and connected edge number: 5, probability distribution length: 256
# 2024-10-09 20:07:16,643 - MLD - DEBUG - detector index: 13, uncomputed and connected edge number: 15, probability distribution length: 512
# 2024-10-09 20:07:16,659 - MLD - DEBUG - detector index: 14, uncomputed and connected edge number: 12, probability distribution length: 256
# 2024-10-09 20:07:16,668 - MLD - DEBUG - detector index: 15, uncomputed and connected edge number: 9, probability distribution length: 512
# 2024-10-09 20:07:16,676 - MLD - DEBUG - detector index: 16, uncomputed and connected edge number: 4, probability distribution length: 256
# 2024-10-09 20:07:16,681 - MLD - DEBUG - detector index: 17, uncomputed and connected edge number: 9, probability distribution length: 128
# 2024-10-09 20:07:16,684 - MLD - DEBUG - detector index: 18, uncomputed and connected edge number: 6, probability distribution length: 64
# 2024-10-09 20:07:16,686 - MLD - DEBUG - detector index: 19, uncomputed and connected edge number: 2, probability distribution length: 32
# 2024-10-09 20:07:16,689 - MLD - DEBUG - detector index: 20, uncomputed and connected edge number: 2, probability distribution length: 16
# 2024-10-09 20:07:16,691 - MLD - DEBUG - detector index: 21, uncomputed and connected edge number: 2, probability distribution length: 8
# 2024-10-09 20:07:16,692 - MLD - DEBUG - detector index: 22, uncomputed and connected edge number: 2, probability distribution length: 4
# 2024-10-09 20:07:16,694 - MLD - DEBUG - detector index: 23, uncomputed and connected edge number: 1, probability distribution length: 2
# 2024-10-09 20:07:16,694 - MLD - INFO - no error, no use logical flip, the correct probability rate is 0.991238732036678
# 2024-10-09 20:07:16,695 - root - INFO - ----------------------r: 5, d: 5-------------------------
# 2024-10-09 20:07:16,706 - MLD - DEBUG - detector index: 0, uncomputed and connected edge number: 3, probability distribution length: 4
# 2024-10-09 20:07:16,708 - MLD - DEBUG - detector index: 1, uncomputed and connected edge number: 7, probability distribution length: 32
# 2024-10-09 20:07:16,722 - MLD - DEBUG - detector index: 2, uncomputed and connected edge number: 18, probability distribution length: 256
# 2024-10-09 20:07:16,730 - MLD - DEBUG - detector index: 3, uncomputed and connected edge number: 8, probability distribution length: 256
# 2024-10-09 20:07:16,737 - MLD - DEBUG - detector index: 4, uncomputed and connected edge number: 7, probability distribution length: 256
# 2024-10-09 20:07:16,776 - MLD - DEBUG - detector index: 5, uncomputed and connected edge number: 22, probability distribution length: 512
# 2024-10-09 20:07:16,823 - MLD - DEBUG - detector index: 6, uncomputed and connected edge number: 20, probability distribution length: 512
# 2024-10-09 20:07:16,907 - MLD - DEBUG - detector index: 7, uncomputed and connected edge number: 16, probability distribution length: 2048
# 2024-10-09 20:07:16,923 - MLD - DEBUG - detector index: 8, uncomputed and connected edge number: 4, probability distribution length: 1024
# 2024-10-09 20:07:17,017 - MLD - DEBUG - detector index: 9, uncomputed and connected edge number: 20, probability distribution length: 1024
# 2024-10-09 20:07:17,063 - MLD - DEBUG - detector index: 10, uncomputed and connected edge number: 17, probability distribution length: 512
# 2024-10-09 20:07:17,073 - MLD - DEBUG - detector index: 11, uncomputed and connected edge number: 8, probability distribution length: 512
# 2024-10-09 20:07:17,084 - MLD - DEBUG - detector index: 12, uncomputed and connected edge number: 7, probability distribution length: 512
# 2024-10-09 20:07:17,162 - MLD - DEBUG - detector index: 13, uncomputed and connected edge number: 21, probability distribution length: 1024
# 2024-10-09 20:07:17,256 - MLD - DEBUG - detector index: 14, uncomputed and connected edge number: 19, probability distribution length: 1024
# 2024-10-09 20:07:17,347 - MLD - DEBUG - detector index: 15, uncomputed and connected edge number: 16, probability distribution length: 2048
# 2024-10-09 20:07:17,367 - MLD - DEBUG - detector index: 16, uncomputed and connected edge number: 4, probability distribution length: 1024
# 2024-10-09 20:07:17,524 - MLD - DEBUG - detector index: 17, uncomputed and connected edge number: 20, probability distribution length: 1024
# 2024-10-09 20:07:17,577 - MLD - DEBUG - detector index: 18, uncomputed and connected edge number: 17, probability distribution length: 512
# 2024-10-09 20:07:17,593 - MLD - DEBUG - detector index: 19, uncomputed and connected edge number: 8, probability distribution length: 512
# 2024-10-09 20:07:17,615 - MLD - DEBUG - detector index: 20, uncomputed and connected edge number: 7, probability distribution length: 512
# 2024-10-09 20:07:17,703 - MLD - DEBUG - detector index: 21, uncomputed and connected edge number: 21, probability distribution length: 1024
# 2024-10-09 20:07:17,793 - MLD - DEBUG - detector index: 22, uncomputed and connected edge number: 19, probability distribution length: 1024
# 2024-10-09 20:07:17,881 - MLD - DEBUG - detector index: 23, uncomputed and connected edge number: 16, probability distribution length: 2048
# 2024-10-09 20:07:17,908 - MLD - DEBUG - detector index: 24, uncomputed and connected edge number: 4, probability distribution length: 1024
# 2024-10-09 20:07:18,011 - MLD - DEBUG - detector index: 25, uncomputed and connected edge number: 20, probability distribution length: 1024
# 2024-10-09 20:07:18,067 - MLD - DEBUG - detector index: 26, uncomputed and connected edge number: 17, probability distribution length: 512
# 2024-10-09 20:07:18,078 - MLD - DEBUG - detector index: 27, uncomputed and connected edge number: 8, probability distribution length: 512
# 2024-10-09 20:07:18,085 - MLD - DEBUG - detector index: 28, uncomputed and connected edge number: 5, probability distribution length: 256
# 2024-10-09 20:07:18,111 - MLD - DEBUG - detector index: 29, uncomputed and connected edge number: 15, probability distribution length: 512
# 2024-10-09 20:07:18,127 - MLD - DEBUG - detector index: 30, uncomputed and connected edge number: 12, probability distribution length: 256
# 2024-10-09 20:07:18,136 - MLD - DEBUG - detector index: 31, uncomputed and connected edge number: 9, probability distribution length: 512
# 2024-10-09 20:07:18,144 - MLD - DEBUG - detector index: 32, uncomputed and connected edge number: 4, probability distribution length: 256
# 2024-10-09 20:07:18,150 - MLD - DEBUG - detector index: 33, uncomputed and connected edge number: 9, probability distribution length: 128
# 2024-10-09 20:07:18,153 - MLD - DEBUG - detector index: 34, uncomputed and connected edge number: 6, probability distribution length: 64
# 2024-10-09 20:07:18,155 - MLD - DEBUG - detector index: 35, uncomputed and connected edge number: 2, probability distribution length: 32
# 2024-10-09 20:07:18,157 - MLD - DEBUG - detector index: 36, uncomputed and connected edge number: 2, probability distribution length: 16
# 2024-10-09 20:07:18,158 - MLD - DEBUG - detector index: 37, uncomputed and connected edge number: 2, probability distribution length: 8
# 2024-10-09 20:07:18,159 - MLD - DEBUG - detector index: 38, uncomputed and connected edge number: 2, probability distribution length: 4
# 2024-10-09 20:07:18,160 - MLD - DEBUG - detector index: 39, uncomputed and connected edge number: 1, probability distribution length: 2
# 2024-10-09 20:07:18,161 - MLD - INFO - no error, no use logical flip, the correct probability rate is 0.9912387503193778
# 2024-10-09 20:07:18,162 - root - INFO - ----------------------r: 7, d: 5-------------------------
# 2024-10-09 20:07:18,172 - MLD - DEBUG - detector index: 0, uncomputed and connected edge number: 3, probability distribution length: 4
# 2024-10-09 20:07:18,175 - MLD - DEBUG - detector index: 1, uncomputed and connected edge number: 7, probability distribution length: 32
# 2024-10-09 20:07:18,190 - MLD - DEBUG - detector index: 2, uncomputed and connected edge number: 18, probability distribution length: 256
# 2024-10-09 20:07:18,198 - MLD - DEBUG - detector index: 3, uncomputed and connected edge number: 8, probability distribution length: 256
# 2024-10-09 20:07:18,205 - MLD - DEBUG - detector index: 4, uncomputed and connected edge number: 7, probability distribution length: 256
# 2024-10-09 20:07:18,241 - MLD - DEBUG - detector index: 5, uncomputed and connected edge number: 22, probability distribution length: 512
# 2024-10-09 20:07:18,285 - MLD - DEBUG - detector index: 6, uncomputed and connected edge number: 20, probability distribution length: 512
# 2024-10-09 20:07:18,389 - MLD - DEBUG - detector index: 7, uncomputed and connected edge number: 16, probability distribution length: 2048
# 2024-10-09 20:07:18,407 - MLD - DEBUG - detector index: 8, uncomputed and connected edge number: 4, probability distribution length: 1024
# 2024-10-09 20:07:18,497 - MLD - DEBUG - detector index: 9, uncomputed and connected edge number: 20, probability distribution length: 1024
# 2024-10-09 20:07:18,545 - MLD - DEBUG - detector index: 10, uncomputed and connected edge number: 17, probability distribution length: 512
# 2024-10-09 20:07:18,563 - MLD - DEBUG - detector index: 11, uncomputed and connected edge number: 8, probability distribution length: 512
# 2024-10-09 20:07:18,574 - MLD - DEBUG - detector index: 12, uncomputed and connected edge number: 5, probability distribution length: 256
# 2024-10-09 20:07:18,599 - MLD - DEBUG - detector index: 13, uncomputed and connected edge number: 15, probability distribution length: 512
# 2024-10-09 20:07:18,616 - MLD - DEBUG - detector index: 14, uncomputed and connected edge number: 12, probability distribution length: 256
# 2024-10-09 20:07:18,627 - MLD - DEBUG - detector index: 15, uncomputed and connected edge number: 9, probability distribution length: 512
# 2024-10-09 20:07:18,632 - MLD - DEBUG - detector index: 16, uncomputed and connected edge number: 4, probability distribution length: 256
# 2024-10-09 20:07:18,637 - MLD - DEBUG - detector index: 17, uncomputed and connected edge number: 9, probability distribution length: 128
# 2024-10-09 20:07:18,641 - MLD - DEBUG - detector index: 18, uncomputed and connected edge number: 6, probability distribution length: 64
# 2024-10-09 20:07:18,642 - MLD - DEBUG - detector index: 19, uncomputed and connected edge number: 2, probability distribution length: 32
# 2024-10-09 20:07:18,644 - MLD - DEBUG - detector index: 20, uncomputed and connected edge number: 2, probability distribution length: 16
# 2024-10-09 20:07:18,645 - MLD - DEBUG - detector index: 21, uncomputed and connected edge number: 2, probability distribution length: 8
# 2024-10-09 20:07:18,646 - MLD - DEBUG - detector index: 22, uncomputed and connected edge number: 2, probability distribution length: 4
# 2024-10-09 20:07:18,647 - MLD - DEBUG - detector index: 23, uncomputed and connected edge number: 1, probability distribution length: 2
# 2024-10-09 20:07:18,649 - MLD - DEBUG - detector index: 24, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,650 - MLD - DEBUG - detector index: 25, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,651 - MLD - DEBUG - detector index: 26, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,653 - MLD - DEBUG - detector index: 27, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,656 - MLD - DEBUG - detector index: 28, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,658 - MLD - DEBUG - detector index: 29, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,659 - MLD - DEBUG - detector index: 30, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,660 - MLD - DEBUG - detector index: 31, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,661 - MLD - DEBUG - detector index: 32, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,662 - MLD - DEBUG - detector index: 33, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,663 - MLD - DEBUG - detector index: 34, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,664 - MLD - DEBUG - detector index: 35, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,665 - MLD - DEBUG - detector index: 36, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,666 - MLD - DEBUG - detector index: 37, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,667 - MLD - DEBUG - detector index: 38, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,668 - MLD - DEBUG - detector index: 39, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,672 - MLD - DEBUG - detector index: 40, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,674 - MLD - DEBUG - detector index: 41, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,677 - MLD - DEBUG - detector index: 42, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,679 - MLD - DEBUG - detector index: 43, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,681 - MLD - DEBUG - detector index: 44, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,683 - MLD - DEBUG - detector index: 45, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,711 - MLD - DEBUG - detector index: 46, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,724 - MLD - DEBUG - detector index: 47, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,734 - MLD - DEBUG - detector index: 48, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,736 - MLD - DEBUG - detector index: 49, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,739 - MLD - DEBUG - detector index: 50, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,740 - MLD - DEBUG - detector index: 51, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,741 - MLD - DEBUG - detector index: 52, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,742 - MLD - DEBUG - detector index: 53, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,743 - MLD - DEBUG - detector index: 54, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,744 - MLD - DEBUG - detector index: 55, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:18,745 - MLD - INFO - no error, no use logical flip, the correct probability rate is 0.9912470516175225
# 2024-10-09 20:07:18,746 - root - INFO - ----------------------r: 9, d: 5-------------------------
# 2024-10-09 20:07:18,751 - MLD - DEBUG - detector index: 0, uncomputed and connected edge number: 3, probability distribution length: 4
# 2024-10-09 20:07:18,755 - MLD - DEBUG - detector index: 1, uncomputed and connected edge number: 7, probability distribution length: 32
# 2024-10-09 20:07:18,768 - MLD - DEBUG - detector index: 2, uncomputed and connected edge number: 18, probability distribution length: 256
# 2024-10-09 20:07:18,781 - MLD - DEBUG - detector index: 3, uncomputed and connected edge number: 8, probability distribution length: 256
# 2024-10-09 20:07:18,789 - MLD - DEBUG - detector index: 4, uncomputed and connected edge number: 7, probability distribution length: 256
# 2024-10-09 20:07:18,830 - MLD - DEBUG - detector index: 5, uncomputed and connected edge number: 22, probability distribution length: 512
# 2024-10-09 20:07:18,876 - MLD - DEBUG - detector index: 6, uncomputed and connected edge number: 20, probability distribution length: 512
# 2024-10-09 20:07:18,976 - MLD - DEBUG - detector index: 7, uncomputed and connected edge number: 16, probability distribution length: 2048
# 2024-10-09 20:07:18,994 - MLD - DEBUG - detector index: 8, uncomputed and connected edge number: 4, probability distribution length: 1024
# 2024-10-09 20:07:19,088 - MLD - DEBUG - detector index: 9, uncomputed and connected edge number: 20, probability distribution length: 1024
# 2024-10-09 20:07:19,133 - MLD - DEBUG - detector index: 10, uncomputed and connected edge number: 17, probability distribution length: 512
# 2024-10-09 20:07:19,149 - MLD - DEBUG - detector index: 11, uncomputed and connected edge number: 8, probability distribution length: 512
# 2024-10-09 20:07:19,158 - MLD - DEBUG - detector index: 12, uncomputed and connected edge number: 5, probability distribution length: 256
# 2024-10-09 20:07:19,183 - MLD - DEBUG - detector index: 13, uncomputed and connected edge number: 15, probability distribution length: 512
# 2024-10-09 20:07:19,200 - MLD - DEBUG - detector index: 14, uncomputed and connected edge number: 12, probability distribution length: 256
# 2024-10-09 20:07:19,211 - MLD - DEBUG - detector index: 15, uncomputed and connected edge number: 9, probability distribution length: 512
# 2024-10-09 20:07:19,217 - MLD - DEBUG - detector index: 16, uncomputed and connected edge number: 4, probability distribution length: 256
# 2024-10-09 20:07:19,224 - MLD - DEBUG - detector index: 17, uncomputed and connected edge number: 9, probability distribution length: 128
# 2024-10-09 20:07:19,226 - MLD - DEBUG - detector index: 18, uncomputed and connected edge number: 6, probability distribution length: 64
# 2024-10-09 20:07:19,228 - MLD - DEBUG - detector index: 19, uncomputed and connected edge number: 2, probability distribution length: 32
# 2024-10-09 20:07:19,229 - MLD - DEBUG - detector index: 20, uncomputed and connected edge number: 2, probability distribution length: 16
# 2024-10-09 20:07:19,231 - MLD - DEBUG - detector index: 21, uncomputed and connected edge number: 2, probability distribution length: 8
# 2024-10-09 20:07:19,232 - MLD - DEBUG - detector index: 22, uncomputed and connected edge number: 2, probability distribution length: 4
# 2024-10-09 20:07:19,233 - MLD - DEBUG - detector index: 23, uncomputed and connected edge number: 1, probability distribution length: 2
# 2024-10-09 20:07:19,234 - MLD - DEBUG - detector index: 24, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,236 - MLD - DEBUG - detector index: 25, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,239 - MLD - DEBUG - detector index: 26, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,242 - MLD - DEBUG - detector index: 27, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,243 - MLD - DEBUG - detector index: 28, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,244 - MLD - DEBUG - detector index: 29, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,245 - MLD - DEBUG - detector index: 30, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,246 - MLD - DEBUG - detector index: 31, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,247 - MLD - DEBUG - detector index: 32, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,248 - MLD - DEBUG - detector index: 33, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,249 - MLD - DEBUG - detector index: 34, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,251 - MLD - DEBUG - detector index: 35, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,255 - MLD - DEBUG - detector index: 36, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,257 - MLD - DEBUG - detector index: 37, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,258 - MLD - DEBUG - detector index: 38, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,259 - MLD - DEBUG - detector index: 39, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,260 - MLD - DEBUG - detector index: 40, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,261 - MLD - DEBUG - detector index: 41, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,262 - MLD - DEBUG - detector index: 42, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,263 - MLD - DEBUG - detector index: 43, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,264 - MLD - DEBUG - detector index: 44, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,266 - MLD - DEBUG - detector index: 45, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,267 - MLD - DEBUG - detector index: 46, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,268 - MLD - DEBUG - detector index: 47, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,269 - MLD - DEBUG - detector index: 48, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,269 - MLD - DEBUG - detector index: 49, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,272 - MLD - DEBUG - detector index: 50, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,275 - MLD - DEBUG - detector index: 51, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,276 - MLD - DEBUG - detector index: 52, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,278 - MLD - DEBUG - detector index: 53, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,279 - MLD - DEBUG - detector index: 54, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,281 - MLD - DEBUG - detector index: 55, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,282 - MLD - DEBUG - detector index: 56, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,284 - MLD - DEBUG - detector index: 57, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,285 - MLD - DEBUG - detector index: 58, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,288 - MLD - DEBUG - detector index: 59, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,290 - MLD - DEBUG - detector index: 60, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,291 - MLD - DEBUG - detector index: 61, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,294 - MLD - DEBUG - detector index: 62, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,295 - MLD - DEBUG - detector index: 63, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,296 - MLD - DEBUG - detector index: 64, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,297 - MLD - DEBUG - detector index: 65, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,298 - MLD - DEBUG - detector index: 66, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,301 - MLD - DEBUG - detector index: 67, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,302 - MLD - DEBUG - detector index: 68, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,306 - MLD - DEBUG - detector index: 69, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,308 - MLD - DEBUG - detector index: 70, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,310 - MLD - DEBUG - detector index: 71, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,311 - MLD - INFO - no error, no use logical flip, the correct probability rate is 0.9912470516175225
# 2024-10-09 20:07:19,313 - root - INFO - ----------------------r: 11, d: 5-------------------------
# 2024-10-09 20:07:19,330 - MLD - DEBUG - detector index: 0, uncomputed and connected edge number: 3, probability distribution length: 4
# 2024-10-09 20:07:19,344 - MLD - DEBUG - detector index: 1, uncomputed and connected edge number: 7, probability distribution length: 32
# 2024-10-09 20:07:19,376 - MLD - DEBUG - detector index: 2, uncomputed and connected edge number: 18, probability distribution length: 256
# 2024-10-09 20:07:19,385 - MLD - DEBUG - detector index: 3, uncomputed and connected edge number: 8, probability distribution length: 256
# 2024-10-09 20:07:19,394 - MLD - DEBUG - detector index: 4, uncomputed and connected edge number: 7, probability distribution length: 256
# 2024-10-09 20:07:19,434 - MLD - DEBUG - detector index: 5, uncomputed and connected edge number: 22, probability distribution length: 512
# 2024-10-09 20:07:19,484 - MLD - DEBUG - detector index: 6, uncomputed and connected edge number: 20, probability distribution length: 512
# 2024-10-09 20:07:19,584 - MLD - DEBUG - detector index: 7, uncomputed and connected edge number: 16, probability distribution length: 2048
# 2024-10-09 20:07:19,602 - MLD - DEBUG - detector index: 8, uncomputed and connected edge number: 4, probability distribution length: 1024
# 2024-10-09 20:07:19,698 - MLD - DEBUG - detector index: 9, uncomputed and connected edge number: 20, probability distribution length: 1024
# 2024-10-09 20:07:19,743 - MLD - DEBUG - detector index: 10, uncomputed and connected edge number: 17, probability distribution length: 512
# 2024-10-09 20:07:19,760 - MLD - DEBUG - detector index: 11, uncomputed and connected edge number: 8, probability distribution length: 512
# 2024-10-09 20:07:19,767 - MLD - DEBUG - detector index: 12, uncomputed and connected edge number: 5, probability distribution length: 256
# 2024-10-09 20:07:19,793 - MLD - DEBUG - detector index: 13, uncomputed and connected edge number: 15, probability distribution length: 512
# 2024-10-09 20:07:19,809 - MLD - DEBUG - detector index: 14, uncomputed and connected edge number: 12, probability distribution length: 256
# 2024-10-09 20:07:19,819 - MLD - DEBUG - detector index: 15, uncomputed and connected edge number: 9, probability distribution length: 512
# 2024-10-09 20:07:19,826 - MLD - DEBUG - detector index: 16, uncomputed and connected edge number: 4, probability distribution length: 256
# 2024-10-09 20:07:19,832 - MLD - DEBUG - detector index: 17, uncomputed and connected edge number: 9, probability distribution length: 128
# 2024-10-09 20:07:19,835 - MLD - DEBUG - detector index: 18, uncomputed and connected edge number: 6, probability distribution length: 64
# 2024-10-09 20:07:19,836 - MLD - DEBUG - detector index: 19, uncomputed and connected edge number: 2, probability distribution length: 32
# 2024-10-09 20:07:19,838 - MLD - DEBUG - detector index: 20, uncomputed and connected edge number: 2, probability distribution length: 16
# 2024-10-09 20:07:19,841 - MLD - DEBUG - detector index: 21, uncomputed and connected edge number: 2, probability distribution length: 8
# 2024-10-09 20:07:19,842 - MLD - DEBUG - detector index: 22, uncomputed and connected edge number: 2, probability distribution length: 4
# 2024-10-09 20:07:19,844 - MLD - DEBUG - detector index: 23, uncomputed and connected edge number: 1, probability distribution length: 2
# 2024-10-09 20:07:19,846 - MLD - DEBUG - detector index: 24, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,847 - MLD - DEBUG - detector index: 25, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,848 - MLD - DEBUG - detector index: 26, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,850 - MLD - DEBUG - detector index: 27, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,851 - MLD - DEBUG - detector index: 28, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,852 - MLD - DEBUG - detector index: 29, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,853 - MLD - DEBUG - detector index: 30, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,853 - MLD - DEBUG - detector index: 31, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,858 - MLD - DEBUG - detector index: 32, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,859 - MLD - DEBUG - detector index: 33, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,860 - MLD - DEBUG - detector index: 34, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,862 - MLD - DEBUG - detector index: 35, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,863 - MLD - DEBUG - detector index: 36, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,864 - MLD - DEBUG - detector index: 37, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,865 - MLD - DEBUG - detector index: 38, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,866 - MLD - DEBUG - detector index: 39, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,868 - MLD - DEBUG - detector index: 40, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,869 - MLD - DEBUG - detector index: 41, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,874 - MLD - DEBUG - detector index: 42, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,876 - MLD - DEBUG - detector index: 43, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,878 - MLD - DEBUG - detector index: 44, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,879 - MLD - DEBUG - detector index: 45, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,880 - MLD - DEBUG - detector index: 46, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,881 - MLD - DEBUG - detector index: 47, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,883 - MLD - DEBUG - detector index: 48, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,884 - MLD - DEBUG - detector index: 49, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,886 - MLD - DEBUG - detector index: 50, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,889 - MLD - DEBUG - detector index: 51, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,891 - MLD - DEBUG - detector index: 52, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,892 - MLD - DEBUG - detector index: 53, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,893 - MLD - DEBUG - detector index: 54, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,895 - MLD - DEBUG - detector index: 55, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,895 - MLD - DEBUG - detector index: 56, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,896 - MLD - DEBUG - detector index: 57, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,897 - MLD - DEBUG - detector index: 58, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,898 - MLD - DEBUG - detector index: 59, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,899 - MLD - DEBUG - detector index: 60, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,900 - MLD - DEBUG - detector index: 61, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,901 - MLD - DEBUG - detector index: 62, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,907 - MLD - DEBUG - detector index: 63, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,909 - MLD - DEBUG - detector index: 64, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,910 - MLD - DEBUG - detector index: 65, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,911 - MLD - DEBUG - detector index: 66, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,912 - MLD - DEBUG - detector index: 67, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,914 - MLD - DEBUG - detector index: 68, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,915 - MLD - DEBUG - detector index: 69, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,917 - MLD - DEBUG - detector index: 70, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,919 - MLD - DEBUG - detector index: 71, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,920 - MLD - DEBUG - detector index: 72, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,924 - MLD - DEBUG - detector index: 73, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,926 - MLD - DEBUG - detector index: 74, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,932 - MLD - DEBUG - detector index: 75, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,933 - MLD - DEBUG - detector index: 76, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,934 - MLD - DEBUG - detector index: 77, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,935 - MLD - DEBUG - detector index: 78, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,944 - MLD - DEBUG - detector index: 79, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,947 - MLD - DEBUG - detector index: 80, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,948 - MLD - DEBUG - detector index: 81, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,949 - MLD - DEBUG - detector index: 82, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,950 - MLD - DEBUG - detector index: 83, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,953 - MLD - DEBUG - detector index: 84, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,956 - MLD - DEBUG - detector index: 85, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,958 - MLD - DEBUG - detector index: 86, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,959 - MLD - DEBUG - detector index: 87, uncomputed and connected edge number: 0, probability distribution length: 2
# 2024-10-09 20:07:19,960 - MLD - INFO - no error, no use logical flip, the correct probability rate is 0.9912470516175225
